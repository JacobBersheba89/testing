# %% [markdown]
# **Modification of column names**
# Read the file *product_prices.csv* into a DataFrame. Modify the names of columns so that they match those in the product_prices_renamed.csv file. Complete two variants of the exercise:
#
# **Using the rename method**
# Overwriting all column names using columns.
# To unify the naming and reduce the risk of a typo, you can use the dictionary below:
#
# {'Name': 'province',
#  'Types of goods': 'product_types',
#  'Measurement unit': 'currency',
#  'id': 'id',
#  'Types of products': 'product_line',
#  'Value': 'value',
#  'Date': 'date'}
#
# The columns method overwrites the columns directly on the object (does not return a new DataFrame), so if you do step 2 first, the hint will be useless (the columns get overwritten).

# %% [markdown]
# Takže prvně jsem si zobrazil oba soubory..

# %%
import pandas as pd

data = pd.read_csv('C:\\Users\\MartinPC\\Desktop\\Kuba kurz\\01_Data\\product_prices.csv', sep=";", decimal=".")
data_rename = pd.read_csv('C:\\Users\\MartinPC\\Desktop\\Kuba kurz\\01_Data\\product_prices_renamed.csv', sep=";", decimal=".")

print(data.head())
print(data_rename.head())
# Out:
#                 Name Goods types Measurement unit  Group ID  \
# 0       SUBCARPATHIA         NaN              PLN         2
# 1               ŁÓDŹ         NaN              PLN         4
# 2  KUYAVIA-POMERANIA         NaN              PLN         2
# 3      LOWER SILESIA         NaN              PLN         2
# 4     WARMIA-MASURIA         NaN              PLN         2
#
#                      Product types  Value     Date
# 0        pork ham cooked - per 1kg  21.37   2013-3
# 1                  bread - per 1kg    NaN   2018-2
# 2  barley groats sausage - per 1kg   3.55  2019-12
# 3       dressed chickens - per 1kg   6.14   2019-2
# 4    Italian head cheese - per 1kg   5.63   2002-3
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# ...

# %%
columns = {
    'Name': 'province',
    'Goods types': 'product_types',
    'Measurement unit': 'currency',
    'Group id': 'product_group_id',
    'Product types': 'product_line',
    'Value': 'value',
    'Date': 'date'
}

data = data.rename(columns=columns)

print("Názvy sloupců v původním souboru:")
print(data)

print("\nNázvy sloupců v přejmenovaném souboru:")
print(data_rename)
# Out:
# Názvy sloupců v původním souboru:
#                  province                       product_types currency  \
# 0            SUBCARPATHIA                                 NaN      PLN
# 1                    ŁÓDŹ                                 NaN      PLN
# 2       KUYAVIA-POMERANIA                                 NaN      PLN
# 3           LOWER SILESIA                                 NaN      PLN
# 4          WARMIA-MASURIA                                 NaN      PLN
# ...                   ...                                 ...      ...
# 149935  KUYAVIA-POMERANIA                                 NaN      PLN
# 149936               ŁÓDŹ  beet sugar white, bagged - per 1kg      PLN
# 149937      LESSER POLAND                                 NaN      PLN
# 149938     WARMIA-MASURIA                                 NaN      PLN
# 149939            MASOVIA                                 NaN      PLN
#
#         Group ID                             product_line  value     date
# ...

# %%
data = data[(data["value"] !=3000) & (data["value"] !=0)]
data[data["province"] == "POLAND"].sort_values(by=["product_types", "value"])

# %% [markdown]
# Dataframe uložit, tak aby zůstaly data 'očištěné'

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#                  province                       product_types currency  \
# 0            SUBCARPATHIA                                 NaN      PLN
# 1                    ŁÓDŹ                                 NaN      PLN
# 2       KUYAVIA-POMERANIA                                 NaN      PLN
# 3           LOWER SILESIA                                 NaN      PLN
# 4          WARMIA-MASURIA                                 NaN      PLN
# ...                   ...                                 ...      ...
# 149933            SILESIA                                 NaN      PLN
# 149934            SILESIA                                 NaN      PLN
# 149935  KUYAVIA-POMERANIA                                 NaN      PLN
# 149936               ŁÓDŹ  beet sugar white, bagged - per 1kg      PLN
# 149938     WARMIA-MASURIA                                 NaN      PLN
#
#         Group ID                       product_line  value     date
# ...

# %%
data.loc[data["province"] == "SUBCARPATHIA" ]

# %% [markdown]
# Vymazání určitých řádků...

# %%
data.dropna(how="any")

print(data)
# Out:
#                  province                       product_types currency  \
# 0            SUBCARPATHIA                                 NaN      PLN
# 1                    ŁÓDŹ                                 NaN      PLN
# 2       KUYAVIA-POMERANIA                                 NaN      PLN
# 3           LOWER SILESIA                                 NaN      PLN
# 4          WARMIA-MASURIA                                 NaN      PLN
# ...                   ...                                 ...      ...
# 149933            SILESIA                                 NaN      PLN
# 149934            SILESIA                                 NaN      PLN
# 149935  KUYAVIA-POMERANIA                                 NaN      PLN
# 149936               ŁÓDŹ  beet sugar white, bagged - per 1kg      PLN
# 149938     WARMIA-MASURIA                                 NaN      PLN
#
#         Group ID                       product_line  value     date
# ...
